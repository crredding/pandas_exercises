# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df = df.loc[:,'school':'guardian']

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
capitalizer = lambda x: x.upper()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'] = df['Mjob'].apply(capitalizer)
df['Fjob'] = df['Mjob'].apply(capitalizer)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME  AT_HOME
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME  AT_HOME
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME  AT_HOME
# 3     GP   F   15       U     GT3       T     4     2   HEALTH   HEALTH
# 4     GP   F   16       U     GT3       T     3     3    OTHER    OTHER
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  SERVICES  SERVICES
# 391     MS   M   17       U     LE3       T     3     1  SERVICES  SERVICES
# 392     MS   M   21       R     GT3       T     1     1     OTHER     OTHER
# 393     MS   M   18       R     LE3       T     3     2  SERVICES  SERVICES
# 394     MS   M   19       U     LE3       T     1     1     OTHER     OTHER
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
#Already completed

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    return x >= 21

# %%
df['legal_drinker'] = df['age'].apply(majority)

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def mult10(x):
    if type(x) is str:
        return x
    else:
        return x * 10

# %%
df.applymap(mult10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   AT_HOME   AT_HOME
# 1       GP   F  170       U     GT3       T    10    10   AT_HOME   AT_HOME
# 2       GP   F  150       U     LE3       T    10    10   AT_HOME   AT_HOME
# 3       GP   F  150       U     GT3       T    40    20    HEALTH    HEALTH
# 4       GP   F  160       U     GT3       T    30    30     OTHER     OTHER
# 5       GP   M  160       U     LE3       T    40    30  SERVICES  SERVICES
# 6       GP   M  160       U     LE3       T    20    20     OTHER     OTHER
# 7       GP   F  170       U     GT3       A    40    40     OTHER     OTHER
# 8       GP   M  150       U     LE3       A    30    20  SERVICES  SERVICES
# 9       GP   M  150       U     GT3       T    30    40     OTHER     OTHER
# 10      GP   F  150       U     GT3       T    40    40   TEACHER   TEACHER
# 11      GP   F  150       U     GT3       T    20    10  SERVICES  SERVICES
# 12      GP   M  150       U     LE3       T    40    40    HEALTH    HEALTH
# 13      GP   M  150       U     GT3       T    40    30   TEACHER   TEACHER
# 14      GP   M  150       U     GT3       A    20    20     OTHER     OTHER
# 15      GP   F  160       U     GT3       T    40    40    HEALTH    HEALTH
# 16      GP   F  160       U     GT3       T    40    40  SERVICES  SERVICES
# 17      GP   F  160       U     GT3       T    30    30     OTHER     OTHER
# 18      GP   M  170       U     GT3       T    30    20  SERVICES  SERVICES
# 19      GP   M  160       U     LE3       T    40    30    HEALTH    HEALTH
# 20      GP   M  150       U     GT3       T    40    30   TEACHER   TEACHER
# 21      GP   M  150       U     GT3       T    40    40    HEALTH    HEALTH
# 22      GP   M  160       U     LE3       T    40    20   TEACHER   TEACHER
# 23      GP   M  160       U     LE3       T    20    20     OTHER     OTHER
# 24      GP   F  150       R     GT3       T    20    40  SERVICES  SERVICES
# 25      GP   F  160       U     GT3       T    20    20  SERVICES  SERVICES
# 26      GP   M  150       U     GT3       T    20    20     OTHER     OTHER
# 27      GP   M  150       U     GT3       T    40    20    HEALTH    HEALTH
# 28      GP   M  160       U     LE3       A    30    40  SERVICES  SERVICES
# 29      GP   M  160       U     GT3       T    40    40   TEACHER   TEACHER
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 365     MS   M  180       R     GT3       T    10    30   AT_HOME   AT_HOME
# 366     MS   M  180       U     LE3       T    40    40   TEACHER   TEACHER
# 367     MS   F  170       R     GT3       T    10    10     OTHER     OTHER
# 368     MS   F  180       U     GT3       T    20    30   AT_HOME   AT_HOME
# 369     MS   F  180       R     GT3       T    40    40     OTHER     OTHER
# 370     MS   F  190       U     LE3       T    30    20  SERVICES  SERVICES
# 371     MS   M  180       R     LE3       T    10    20   AT_HOME   AT_HOME
# 372     MS   F  170       U     GT3       T    20    20     OTHER     OTHER
# 373     MS   F  170       R     GT3       T    10    20     OTHER     OTHER
# 374     MS   F  180       R     LE3       T    40    40     OTHER     OTHER
# 375     MS   F  180       R     GT3       T    10    10     OTHER     OTHER
# 376     MS   F  200       U     GT3       T    40    20    HEALTH    HEALTH
# 377     MS   F  180       R     LE3       T    40    40   TEACHER   TEACHER
# 378     MS   F  180       U     GT3       T    30    30     OTHER     OTHER
# 379     MS   F  170       R     GT3       T    30    10   AT_HOME   AT_HOME
# 380     MS   M  180       U     GT3       T    40    40   TEACHER   TEACHER
# 381     MS   M  180       R     GT3       T    20    10     OTHER     OTHER
# 382     MS   M  170       U     GT3       T    20    30     OTHER     OTHER
# 383     MS   M  190       R     GT3       T    10    10     OTHER     OTHER
# 384     MS   M  180       R     GT3       T    40    20     OTHER     OTHER
# 385     MS   F  180       R     GT3       T    20    20   AT_HOME   AT_HOME
# 386     MS   F  180       R     GT3       T    40    40   TEACHER   TEACHER
# 387     MS   F  190       R     GT3       T    20    30  SERVICES  SERVICES
# 388     MS   F  180       U     LE3       T    30    10   TEACHER   TEACHER
# 389     MS   F  180       U     GT3       T    10    10     OTHER     OTHER
# 390     MS   M  200       U     LE3       A    20    20  SERVICES  SERVICES
# 391     MS   M  170       U     LE3       T    30    10  SERVICES  SERVICES
# 392     MS   M  210       R     GT3       T    10    10     OTHER     OTHER
# 393     MS   M  180       R     LE3       T    30    20  SERVICES  SERVICES
# 394     MS   M  190       U     LE3       T    10    10     OTHER     OTHER
#
#          reason guardian  legal_drinker
# 0        course   mother              0
# 1        course   father              0
# 2         other   mother              0
# 3          home   mother              0
# 4          home   father              0
# 5    reputation   mother              0
# 6          home   mother              0
# 7          home   mother              0
# 8          home   mother              0
# 9          home   mother              0
# 10   reputation   mother              0
# 11   reputation   father              0
# 12       course   father              0
# 13       course   mother              0
# 14         home    other              0
# 15         home   mother              0
# 16   reputation   mother              0
# 17   reputation   mother              0
# 18       course   mother              0
# 19         home   father              0
# 20   reputation   mother              0
# 21        other   father              0
# 22       course   mother              0
# 23   reputation   mother              0
# 24       course   mother              0
# 25         home   mother              0
# 26         home   mother              0
# 27        other   mother              0
# 28         home   mother              0
# 29         home   mother              0
# ..          ...      ...            ...
# 365      course   mother              0
# 366       other   mother              0
# 367  reputation   mother              0
# 368      course   father              0
# 369       other   father              0
# 370        home    other              0
# 371       other   father              0
# 372        home   mother              0
# 373      course   mother              0
# 374  reputation   mother              0
# 375        home   mother              0
# 376      course    other              0
# 377      course   mother              0
# 378        home   mother              0
# 379  reputation   mother              0
# 380        home   father              0
# 381       other   mother              0
# 382        home   father              0
# 383       other   mother              0
# 384        home   father              0
# 385       other   mother              0
# 386  reputation   mother              0
# 387      course   mother              0
# 388      course   mother              0
# 389      course   mother              0
# 390      course    other              0
# 391      course   mother              0
# 392      course    other             10
# 393      course   mother              0
# 394      course   father              0
#
# [395 rows x 13 columns]
